# %%
from pyALF import *

# %%
compile_alf()

# %%
sim = {"Model": "Hubbard", "Lattice_type": "Square",    "L1": 6 , "L2": 6, "NBin": 5}

# %%
run(sim, executable="Examples.out")

# %%
ana(sim)
# Out:
# Analysing Part_scal
# Analysing Kin_scal
# Analysing Ener_scal
# Analysing Pot_scal
# Analysing SpinZ_eq
# Analysing Green_eq
# Analysing Den_eq
# Analysing SpinZ_tau
# Analysing Den_tau
# Analysing Green_tau

# %%
obs = get_obs(sim)

# %%
obs.keys()
# Out:
# dict_keys(['SpinZ_eqJR', 'SpinZ_eqJK', 'Den_eqJR', 'Den_eqJK', 'Green_eqJR', 'Pot_scalJ', 'Green_eqJK', 'Ener_scalJ', 'Kin_scalJ', 'Part_scalJ'])

# %%
obs['Ener_scalJ']
# Out:
# {'sign': array([1., 0.]), 'obs': array([[-29.057328,   0.302572]])}

# %%
obs['SpinZ_eqJK']['dat']
# Out:
# array([[[[9.09705870e-01, 4.91039000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[6.17825800e-01, 6.21350000e-04, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[5.35507720e-01, 9.38740000e-04, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[6.17136140e-01, 2.33907000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[9.03092620e-01, 4.68061000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[1.08363136e+00, 7.10254000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[6.21092060e-01, 4.58129000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[4.30317120e-01, 1.21184000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[3.20607430e-01, 1.03787000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
#        [[[4.33794330e-01, 2.56482000e-03, 0.00000000e+00,
#           0.00000000e+00]]],
#
#
# ...

# %%
obs['SpinZ_eqJK']['k']
# Out:
# array([[-2.094395, -2.094395],
#        [-2.094395, -1.047198],
#        [-2.094395,  0.      ],
#        [-2.094395,  1.047198],
#        [-2.094395,  2.094395],
#        [-2.094395,  3.141593],
#        [-1.047198, -2.094395],
#        [-1.047198, -1.047198],
#        [-1.047198,  0.      ],
#        [-1.047198,  1.047198],
#        [-1.047198,  2.094395],
#        [-1.047198,  3.141593],
#        [ 0.      , -2.094395],
#        [ 0.      , -1.047198],
#        [ 0.      ,  0.      ],
#        [ 0.      ,  1.047198],
#        [ 0.      ,  2.094395],
#        [ 0.      ,  3.141593],
#        [ 1.047198, -2.094395],
#        [ 1.047198, -1.047198],
#        [ 1.047198,  0.      ],
#        [ 1.047198,  1.047198],
#        [ 1.047198,  2.094395],
#        [ 1.047198,  3.141593],
#        [ 2.094395, -2.094395],
#        [ 2.094395, -1.047198],
#        [ 2.094395,  0.      ],
#        [ 2.094395,  1.047198],
#        [ 2.094395,  2.094395],
#        [ 2.094395,  3.141593],
# ...
