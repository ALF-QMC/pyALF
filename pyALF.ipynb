# %%
from py_alf import Simulation

# %%
sim = Simulation({
    "Model": "Hubbard",
    "Lattice_type": "Square",
    "L1": 6,
    "L2": 6,
    "NBin": 5},
    executable="Examples"
)

# %%
sim.compile()

# %%
sim.run()
# Out:
# Prepare directory /home/jonas/Programs/pyALF/Hubbard_Square_L1=6_L2=6 for Monte Carlo run
# Run /home/jonas/Programs/pyALF/ALF/Prog/Examples.out
# stderr:
# stdout:  ALF Copyright (C) 2016 - 2020 The ALF project contributors
#  This Program comes with ABSOLUTELY NO WARRANTY; for details see license.GPL
#  This is free software, and you are welcome to redistribute it under certain conditions.
#  unable to open <parameters>           2

# %%
sim.ana()

# %%
obs = sim.get_obs()

# %%
obs.keys()
# Out:
# dict_keys(['SpinZ_eqJR', 'SpinZ_eqJK', 'Den_eqJR', 'Den_eqJK', 'Green_eqJR', 'Pot_scalJ', 'Green_eqJK', 'Ener_scalJ', 'Kin_scalJ', 'Part_scalJ'])

# %%
obs['Ener_scalJ']
# Out:
# {'sign': array([1., 0.]), 'obs': array([[-30.183641,   0.944801]])}

# %%
obs['SpinZ_eqJK']['dat']
# Out:
# array([[[[ 9.37742090e-01,  2.90718200e-02, -0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 6.15728680e-01,  2.30865000e-03,  0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 5.47635920e-01,  1.04708500e-02, -0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 6.25213250e-01,  5.28685000e-03, -0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 9.12819580e-01,  5.83703000e-03,  0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 1.10330952e+00,  1.72798200e-02, -0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 6.26927310e-01,  5.45524000e-03, -0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 4.31203850e-01,  1.53411000e-03,  0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 3.24672100e-01,  4.85296000e-03,  0.00000000e+00,
#            0.00000000e+00]]],
#
#
#        [[[ 4.39693870e-01,  2.30844000e-03, -0.00000000e+00,
#            0.00000000e+00]]],
#
#
# ...

# %%
obs['SpinZ_eqJK']['k']
# Out:
# array([[-2.094395, -2.094395],
#        [-2.094395, -1.047198],
#        [-2.094395,  0.      ],
#        [-2.094395,  1.047198],
#        [-2.094395,  2.094395],
#        [-2.094395,  3.141593],
#        [-1.047198, -2.094395],
#        [-1.047198, -1.047198],
#        [-1.047198,  0.      ],
#        [-1.047198,  1.047198],
#        [-1.047198,  2.094395],
#        [-1.047198,  3.141593],
#        [ 0.      , -2.094395],
#        [ 0.      , -1.047198],
#        [ 0.      ,  0.      ],
#        [ 0.      ,  1.047198],
#        [ 0.      ,  2.094395],
#        [ 0.      ,  3.141593],
#        [ 1.047198, -2.094395],
#        [ 1.047198, -1.047198],
#        [ 1.047198,  0.      ],
#        [ 1.047198,  1.047198],
#        [ 1.047198,  2.094395],
#        [ 1.047198,  3.141593],
#        [ 2.094395, -2.094395],
#        [ 2.094395, -1.047198],
#        [ 2.094395,  0.      ],
#        [ 2.094395,  1.047198],
#        [ 2.094395,  2.094395],
#        [ 2.094395,  3.141593],
# ...
