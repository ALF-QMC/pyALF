# %%
from py_alf import analysis
from py_alf.ana import load_res
import numpy as np
import matplotlib.pyplot as plt

# %%
analysis("/home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Notebooks/ALF_data/Test")
# Out:
# ### Analyzing /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Notebooks/ALF_data/Test ###
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Notebooks
# Scalar observables:
# Ener_scal
# Kin_scal
# Part_scal
# Pot_scal
# Histogram observables:
# Equal time observables:
# Den_eq
# Green_eq
# SpinT_eq
# SpinXY_eq
# SpinZ_eq
# Time displaced observables:

# %%
obs = load_res("/home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Notebooks/ALF_data/Test/")
#help(simulation.get_obs)
# Out:
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Notebooks/ALF_data/Test/

# %%
obs
# Out:
#                                                     continuous  ham_chem  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...           0       0.0
#
#                                                     ham_t  ham_t2  ham_tperp  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...    1.0     0.0        0.0
#
#                                                     ham_u  ham_u2  mz  l1  l2  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...    4.0     0.0   1  26   1
#
#                                                     ...  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  ...
#
#                                                                                     SpinXY_eq_lattice  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  {'L1': [26.0, 0.0], 'L2': [0.0, 1.0], 'a1': [1...
#
#                                                                                             SpinZ_eqK  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [[[1.9818005374029768, 1.4301065626559835, 1.1...
#
#                                                                                         SpinZ_eqK_err  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [[[0.0032321205452294837, 0.00119423333677221,...
#
#                                                                                         SpinZ_eqK_sum  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [1.9818005374029768, 1.4301065626559835, 1.150...
#
#                                                                                     SpinZ_eqK_sum_err  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [0.0032321205452294837, 0.00119423333677221, 0...
#
#                                                                                             SpinZ_eqR  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [[[0.01695453557141523, -0.018421882272092457,...
#
#                                                                                         SpinZ_eqR_err  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [[[0.0005586951029599106, 0.000561105971330820...
#
#                                                                                         SpinZ_eqR_sum  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [0.01695453557141523, -0.018421882272092457, 0...
#
#                                                                                     SpinZ_eqR_sum_err  \
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  [0.0005586951029599106, 0.0005611059713308207,...
#
#                                                                                      SpinZ_eq_lattice
# /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Note...  {'L1': [26.0, 0.0], 'L2': [0.0, 1.0], 'a1': [1...
#
# [1 rows x 85 columns]

# %%
obs.iloc[0]
# Out:
# continuous                                                           0
# ham_chem                                                             0
# ham_t                                                                1
# ham_t2                                                               0
# ham_tperp                                                            0
#                                            ...
# SpinZ_eqR            [[[0.01695453557141523, -0.018421882272092457,...
# SpinZ_eqR_err        [[[0.0005586951029599106, 0.000561105971330820...
# SpinZ_eqR_sum        [0.01695453557141523, -0.018421882272092457, 0...
# SpinZ_eqR_sum_err    [0.0005586951029599106, 0.0005611059713308207,...
# SpinZ_eq_lattice     {'L1': [26.0, 0.0], 'L2': [0.0, 1.0], 'a1': [1...
# Name: /home/stafusa/Jobs/Uni-Wuerzburg/ALF/pyALF/Notebooks/ALF_data/Test/, Length: 85, dtype: object

# %%
x = np.arange(26)
y = obs['SpinZ_eqR'][0][0][0]
yerr = obs['SpinZ_eqR_err'][0][0][0]
plt.errorbar(x,y,yerr)
plt.show()

# %%
fig, ax = plt.subplots()
ax.errorbar(x-12,y,yerr)
ax.set_xlim([0,13])
ax.set_xlabel('R')
ax.set_ylabel('S(0)S(R)');
